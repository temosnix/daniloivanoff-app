# %%
data = dict('{"paging":null,"conversation_status":null,"messages":[{"id":"1200bc6bd42448819d358a5f9122f7bf","site_id":"MLB","client_id":null,"from":{"user_id":243441421},"to":{"user_id":34977269},"status":"available","subject":null,"text":"Boa noite fiz a compra e um Vectra 2009 sedam ","message_date":{"received":"2023-08-25T00:52:30Z","available":"2023-08-25T00:52:30Z","notified":"2023-08-25T00:52:30Z","created":"2023-08-25T00:52:30Z","read":null},"message_moderation":{"is_automatic":false,"status":"clean","reason":"","source":"online","moderation_date":null},"message_attachments":null,"message_resources":[{"id":"2000006330355766","name":"packs"},{"id":"34977269","name":"sellers"}],"conversation_first_message":false}],"seller_max_message_length":0,"buyer_max_message_length":0}')
print(data['messeges']['text'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 data = dict('{"paging":null,"conversation_status":null,"messages":[{"id":"1200bc6bd42448819d358a5f9122f7bf","site_id":"MLB","client_id":null,"from":{"user_id":243441421},"to":{"user_id":34977269},"status":"available","subject":null,"text":"Boa noite fiz a compra e um Vectra 2009 sedam ","message_date":{"received":"2023-08-25T00:52:30Z","available":"2023-08-25T00:52:30Z","notified":"2023-08-25T00:52:30Z","created":"2023-08-25T00:52:30Z","read":null},"message_moderation":{"is_automatic":false,"status":"clean","reason":"","source":"online","moderation_date":null},"message_attachments":null,"message_resources":[{"id":"2000006330355766","name":"packs"},{"id":"34977269","name":"sellers"}],"conversation_first_message":false}],"seller_max_message_length":0,"buyer_max_message_length":0}')
# ...

# %%
from datetime import datetime
dia_atual = datetime.now().day
j_dict = [ 'date_created: 23-08-24']

print(dia_atual)
# Out:
# 24

# %%
import json

def teste():
      data = '''{
                "_id": "2d0edf52-1e8e-4e51-a9d1-48ee6d6735d5",
                "topic": "questions",
                "resource": "/questions/12808956513",
                "user_id": 34977269,
                "application_id": 2417001236894079,
                "sent": "2023-08-16T13:01:38.48Z",
                "attempts": 1,
                "received": "2023-08-16T13:01:38.443Z"
            }'''
      data_dict = json.loads(data)
      id_pergunta = data_dict['resource'].split("/")[-1]
      print(id_pergunta)
      
teste()
# Out:
# 12808956513

# %%
import requests
import json



def tratar_informacao():
    data = '''{
                "_id": "2d0edf52-1e8e-4e51-a9d1-48ee6d6735d5",
                "topic": "questions",
                "resource": "/questions/12811261908",
                "user_id": 34977269,
                "application_id": 2417001236894079,
                "sent": "2023-08-16T13:01:38.48Z",
                "attempts": 1,
                "received": "2023-08-16T13:01:38.443Z"
            }'''
    data_dict = json.loads(data)

    topico = data_dict['topic']
 

    if topico == 'questions':
        
        
        id_pergunta = data_dict['resource'].split("/")[-1]

        url = f"https://api.mercadolibre.com/questions/{id_pergunta}"

        payload = {}
        headers = {
        'Authorization': 'Bearer APP_USR-2417001236894079-082408-761ea9327518bb81a889297a5450437b-34977269'
        }

        response = requests.request("GET", url, headers=headers, data=payload)
        print(f"Pergunta: {response.json()['text']}\n Resposta : {response.json()['answer']['text']}" )
        '''if response.json()['status'] == "ANSWERED":
            print(f"Pergunta: {response.json()['text']}\n Resposta : {response.json()['answer']['text']}" )

        else:
            print(f"Pergunta: {response.json()['text']}\n Aguardando Resposta")'''


        
    else:
        
        print('topco nao encontrado ')
    
tratar_informacao()

#{"id":12808956513,"seller_id":34977269,"text":"Bom dia Esses amortecedores é recondicionado????","tags":null,"status":"ANSWERED","item_id":"MLB1825729785","date_created":"2023-08-16T08:53:33.683-04:00","hold":false,"deleted_from_listing":false,"answer":{"text":"Bom dia os amortecedores sao remanufaturados","status":"ACTIVE","date_created":"2023-08-16T09:01:37.975-04:00"},"from":{"id":217299517,"answered_questions":1}}
# Out:
# Pergunta: Bom dia, o Coxim traseiro é Oval ??
#  Resposta : bom dia, oval

# %%
import requests
from datetime import datetime
import json



def Vendas (data):
    j_dict = json.loads(data)
    topico = j_dict['topic']
    print(topico)

    if topico == "orders_v2":
        id_venda = j_dict['resource'].split("/")[-1]
        print(id_venda)
        
        url = f"https://api.mercadolibre.com/orders/{id_venda}"

        payload = {}
        headers = {
        'Authorization': 'Bearer APP_USR-2417001236894079-082408-761ea9327518bb81a889297a5450437b-34977269'
        }

        response = requests.request("GET", url, headers=headers, data=payload)

        print(response.text)

        arquivo = response.json()

   
        print(arquivo['tags'])
        id_compra = arquivo["id"]
        primeiro_item = arquivo["order_items"][0]["item"]
        item_id = primeiro_item["id"]
        item_title = primeiro_item["title"]
        quantidade = arquivo["order_items"][0]["quantity"]

        comprador = arquivo['buyer']
        date_created = arquivo['date_created']
        nickname = comprador['nickname']
        nome = comprador['first_name'] + " " + comprador['last_name']

        data_hora_atual = datetime.now()
        dia_atual = data_hora_atual.day
        mes_atual = data_hora_atual.month
        ano_atual = data_hora_atual.year

        data_obj = datetime.strptime(date_created, "%Y-%m-%dT%H:%M:%S.%f%z")
        data_compra = data_obj.strftime("%d-%m-%y")
        dia_compra = data_obj.day
        mes_compra = data_obj.month
        ano_compra = data_obj.year

        print(f'\n id da compra : {id_compra} \n\n data da compra: {data_compra}\n\n id do anuncio: {item_id} \n\n titulo do anuncio: {item_title}\n\n nome do cliente :{nome}\n\n quantidade: {quantidade}\n' )

        if item_id == 'MLB2015443547' and (dia_atual - 1) == dia_compra:
            print(' uma nova compra do civic 2012 saiu, perguntar para o cliente se é 2.0 ou 1.8')

           

            url = f"https://api.mercadolibre.com/messages/action_guide/packs/{id_compra}/option"

            headers = {
                "Authorization": "Bearer APP_USR-2417001236894079-082408-761ea9327518bb81a889297a5450437b-34977269",
                "Content-Type": "application/json"
            }

            data = {
                "option_id": "OTHER",
                "text": f"Olá {nome}, existe 2 tipos de amortecedor para seu carro. Me confirma se seu carro é 1.8 ou 2.0?"
            }

            response = requests.post(url, headers=headers, json=data)

            print(response.status_code)
            print(response.text)

      



data = '''{
    "_id": "a1c70494-0b1e-4e67-bd02-c54be88b6d02",
    "topic": "orders_v2",
    "resource": "/orders/2000006307490704",
    "user_id": 34977269,
    "application_id": 2417001236894079,
    "sent": "2023-08-23T12:31:54.669Z",
    "attempts": 1,
    "received": "2023-08-23T12:31:54.583Z"
    }'''
Vendas(data)
# Out:
# orders_v2
# 2000006307490704
# ...

# %%
import requests
import json


def pack(id):

  
  url = f"https://api.mercadolibre.com/messages/packs/{id}/sellers/34977269?tag=post_sale"

  payload = {}
  headers = {
      'Authorization': 'Bearer APP_USR-2417001236894079-082507-a8c030e7678e770e9de340f612cc1ecc-34977269'
  }

  response = requests.request("GET", url, headers=headers, data=payload)

  total_msg = int(response.json()['paging']['total'])
 
  if total_msg > 10 :
    total_msg = 10
 

  for i in range(total_msg - 1, -1, -1):
    
    usuario = (response.json()['messages'][i]['from']['user_id'])
    if usuario == 34977269:

      print(f"  Dfast :{response.json()['messages'][i]['text']}")
    else:
      print(f"Comprador :{response.json()['messages'][i]['text']}")

def mensagens(data):

    j_dict = json.loads(data)
    resource = j_dict["resource"]
    
    url =f"https://api.mercadolibre.com/messages/{resource}?tag=post_sale"

    payload = {}
    headers = {
    'Authorization': 'Bearer APP_USR-2417001236894079-082507-a8c030e7678e770e9de340f612cc1ecc-34977269'
    }

    response = requests.request("GET", url, headers=headers, data=payload)

    pack(response.json()['messages'][0]['message_resources'][0]['id'])

data = '''{
"_id": "2a402d26-b1e0-4695-b039-f5e1c6cdf351",
"topic": "messages",
"resource": "e169f389bab442e2869216866c5927d0",
"user_id": 34977269,
"application_id": 2417001236894079,
"sent": "2023-08-23T13:30:22.234Z",
"attempts": 1,
"received": "2023-08-23T13:30:22.177Z"
}'''

mensagens(data)
# Out:
#   Dfast :as molas tenho. mas ja comprou, o mercadolivre tem horas que nao notifica que veio mensagem
#   Dfast :Tem que ficar procurando as mensagens
# Comprador :Entendo.
# Comprador :Preciso de uma fechadura traseira esquerda. Jetta 2.0 2013. Conforteline
#   Dfast :temos somente peças de suspensao e coxins
#
# Comprador :Ok. Fico no aguardo.  De já agradeço sua atenção.
# Comprador :Bom dia.
# Comprador :Alguma novidade?
#   Dfast :me passa seu whatsapp
# Comprador :63 992103998

# %%
import requests
import json


def pack(data):

  j_dict = json.loads(data)
  resource = j_dict["resource"]
  print(resource)

  url = "https://api.mercadolibre.com/messages/packs/2000006166112506/sellers/34977269?tag=post_sale"

  payload = {}
  headers = {
      'Authorization': 'Bearer APP_USR-2417001236894079-082507-a8c030e7678e770e9de340f612cc1ecc-34977269'
  }

  response = requests.request("GET", url, headers=headers, data=payload)
  status = response.json()["conversation_status"]['status']
  total_msg = int(response.json()['paging']['total'])
  for i in range(total_msg - 1, -1, -1):
    print(i)
    usuario = (response.json()['messages'][i]['from']['user_id'])
    if usuario == 34977269:

      print(f"Dfast :{response.json()['messages'][i]['text']}")
    else:
      print(f"Comprador :{response.json()['messages'][i]['text']}")
# Out:
# 6dc754d95b444a389b992d805027469b
# 4
# Comprador :Bom dia os amortecedores dianteiro deu defeito
# 3
# Dfast :Bom dia qual lado
# 2
# Comprador :Os dois lados um tá casando óleo e outro não tá amortecendo
# 1
# Dfast :Nos passe seu whatsapp que vamos enviar o quanto antes
# 0
# Comprador :62992261158
# ...

# %%
import requests
import json

def questions(data):
    j_dict = json.loads(data)
    resource = j_dict["resource"].split("/")[-1]
    print(resource)


    url = f"https://api.mercadolibre.com/questions/{resource}"

    payload = {}
    headers = {
    'Authorization': 'Bearer APP_USR-2417001236894079-082408-761ea9327518bb81a889297a5450437b-34977269'
    }

    response = requests.request("GET", url, headers=headers, data=payload)

    print(response.text)

    if response.json()['status'] == 'ANSWERED':
        print(f' Pergunta:{response.json()["text"]}')
        print(f'   Resposta: {response.json()["answer"]["text"]}')
    else:
         print(f' Pergunta:{response.json()["text"]}')
         print(f'   Resposta:')

    print(response.status_code)



data= '''{
"_id": "6ca8e9f5-8cc8-426c-a2ec-1fe02b1ea1d9",
"topic": "questions",
"resource": "/questions/12816699938",
"user_id": 34977269,
"application_id": 2417001236894079,
"sent": "2023-08-23T15:08:44.894Z",
"attempts": 2,
"received": "2023-08-23T15:07:41.541Z"
}'''

questions(data)
# Out:
# 12816699938
# {"id":12816699938,"seller_id":34977269,"text":"Da certo no 2009?","tags":null,"status":"ANSWERED","item_id":"MLB1933858201","date_created":"2023-08-24T09:28:50.637-04:00","hold":false,"deleted_from_listing":false,"answer":{"text":"Bom dia, serve sim","status":"ACTIVE","date_created":"2023-08-24T09:39:52.525-04:00"},"from":{"id":225014065,"answered_questions":1}}
#  Pergunta:Da certo no 2009?
#    Resposta: Bom dia, serve sim
# 200
